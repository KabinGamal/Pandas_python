# %%
import pandas as pd

# %% [markdown]
# # Basically their are two type of data in pandas
# 1. series (1D)
# 2. DataFrame (2D)

# %% [markdown]
# For the series

# %%
cars=pd.Series(["BMW","Mercedes","Porsche"])
cars
# Out:
# 0         BMW
# 1    Mercedes
# 2     Porsche
# dtype: object

# %%
color=pd.Series(["Grey","Black","Golden","Red"])
color
# Out:
# 0      Grey
# 1     Black
# 2    Golden
# 3       Red
# dtype: object

# %% [markdown]
# For the dataFrame

# %%
df=pd.DataFrame({"Cars":cars,"Color":color})

# %%
cars[3]="Kabin"

# %%
cars
# Out:
# 0         BMW
# 1    Mercedes
# 2     Porsche
# 3       Kabin
# dtype: object

# %%
students=(["kabin","Sushnat","Remon","Aayush"])

# %%
roll=([1,2,3,4,])

# %%
roll
# Out:
# [1, 2, 3, 4]

# %%
att=pd.DataFrame({
    "Name":students,
    "Roll":roll
})

# %%
att
# Out:
#       Name  Roll
# 0    kabin     1
# 1  Sushnat     2
# 2    Remon     3
# 3   Aayush     4

# %%
car_sales=pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns=car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns[1]
# Out:
# 'Colour'

# %% [markdown]
#  ## Describing Data

# %%
car_sales.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.isnull()
# Out:
#     Make  Colour  Odometer (KM)  Doors  Price
# 0  False   False          False  False  False
# 1  False   False          False  False  False
# 2  False   False          False  False  False
# 3  False   False          False  False  False
# 4  False   False          False  False  False
# 5  False   False          False  False  False
# 6  False   False          False  False  False
# 7  False   False          False  False  False
# 8  False   False          False  False  False
# 9  False   False          False  False  False

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ## Selecting and Viewing data

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## for .loc it refers to the location

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
food=pd.Series(["momo","choclate","pizza","honey","Water"],index=[4,5,6,4,1])

# %%
food
# Out:
# 4        momo
# 5    choclate
# 6       pizza
# 4       honey
# 1       Water
# dtype: object

# %%
food.loc[4]
# Out:
# 4     momo
# 4    honey
# dtype: object

# %%
food.iloc[1]
# Out:
# 'choclate'

# %%
car_sales.iloc[2]
# Out:
# Make                Toyota
# Colour                Blue
# Odometer (KM)        32549
# Doors                    3
# Price            $7,000.00
# Name: 2, dtype: object

# %%
 car_sales[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales[car_sales["Make"]=="Toyota" ]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales[["Odometer (KM)"]].hist()
# Out:
# array([[<Axes: title={'center': 'Odometer (KM)'}>]], dtype=object)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_sales["Price"]
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_sales["Price"]
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_sales["Price"]=pd.to_numeric(
    car_sales["Price"].replace(r"[$,.]","",regex=True )
)

# %%
car_sales["Price"].dtype
# Out:
# dtype('int64')

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales["Price"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"]=car_sales["Price"].astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price_display"]=car_sales["Price"].apply(lambda x: f"${x:,}")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Price_display
# 0  Toyota  White         150043      4   400000      $400,000
# 1   Honda    Red          87899      4   500000      $500,000
# 2  Toyota   Blue          32549      3   700000      $700,000
# 3     BMW  Black          11179      5  2200000    $2,200,000
# 4  Nissan  White         213095      4   350000      $350,000
# 5  Toyota  Green          99213      4   450000      $450,000
# 6   Honda   Blue          45698      4   750000      $750,000
# 7   Honda   Blue          54738      4   700000      $700,000
# 8  Toyota  White          60000      4   625000      $625,000
# 9  Nissan  White          31600      4   970000      $970,000

# %%
car_sales["Make"]=car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Price_display
# 0  toyota  White         150043      4   400000      $400,000
# 1   honda    Red          87899      4   500000      $500,000
# 2  toyota   Blue          32549      3   700000      $700,000
# 3     bmw  Black          11179      5  2200000    $2,200,000
# 4  nissan  White         213095      4   350000      $350,000
# 5  toyota  Green          99213      4   450000      $450,000
# 6   honda   Blue          45698      4   750000      $750,000
# 7   honda   Blue          54738      4   700000      $700,000
# 8  toyota  White          60000      4   625000      $625,000
# 9  nissan  White          31600      4   970000      $970,000

# %%
car_sales["Make"].apply(lambda x: str.upper(x))
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: object

# %%
car_sales["Price"]=car_sales["Price"]*10

# %%
car_sales["Price"]=car_sales["Price"].astype(int)

# %%
car_sales["Price_display"]=car_sales["Price"].apply(lambda x:f"${x:,}")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price Price_display
# 0  toyota  White         150043      4   4000000    $4,000,000
# 1   honda    Red          87899      4   5000000    $5,000,000
# 2  toyota   Blue          32549      3   7000000    $7,000,000
# 3     bmw  Black          11179      5  22000000   $22,000,000
# 4  nissan  White         213095      4   3500000    $3,500,000
# 5  toyota  Green          99213      4   4500000    $4,500,000
# 6   honda   Blue          45698      4   7500000    $7,500,000
# 7   honda   Blue          54738      4   7000000    $7,000,000
# 8  toyota  White          60000      4   6250000    $6,250,000
# 9  nissan  White          31600      4   9700000    $9,700,000

# %%
car_sales["Price_display"]
# Out:
# 0     $4,000,000
# 1     $5,000,000
# 2     $7,000,000
# 3    $22,000,000
# 4     $3,500,000
# 5     $4,500,000
# 6     $7,500,000
# 7     $7,000,000
# 8     $6,250,000
# 9     $9,700,000
# Name: Price_display, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price Price_display
# 0  toyota  White         150043      4   4000000    $4,000,000
# 1   honda    Red          87899      4   5000000    $5,000,000
# 2  toyota   Blue          32549      3   7000000    $7,000,000
# 3     bmw  Black          11179      5  22000000   $22,000,000
# 4  nissan  White         213095      4   3500000    $3,500,000
# 5  toyota  Green          99213      4   4500000    $4,500,000
# 6   honda   Blue          45698      4   7500000    $7,500,000
# 7   honda   Blue          54738      4   7000000    $7,000,000
# 8  toyota  White          60000      4   6250000    $6,250,000
# 9  nissan  White          31600      4   9700000    $9,700,000

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_drop=car_sales_missing.dropna()

# %%
car_sales_missing_drop
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing["Odometer"]
# Out:
# 0    150043.0
# 1     87899.0
# 2         NaN
# 3     11179.0
# 4    213095.0
# 5         NaN
# 6         NaN
# 7         NaN
# 8     60000.0
# 9     31600.0
# Name: Odometer, dtype: float64

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean()).astype(int)
# Out:
# 0    150043
# 1     87899
# 2     92302
# 3     11179
# 4    213095
# 5     92302
# 6     92302
# 7     92302
# 8     60000
# 9     31600
# Name: Odometer, dtype: int64

# %%
car_sales_missing.plot(kind="bar")
# Out:
# <Axes: >

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_drop.plot(kind="bar")
# Out:
# <Axes: >

# %%
car_sales_missing_drop
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price Price_display
# 0  toyota  White         150043      4   4000000    $4,000,000
# 1   honda    Red          87899      4   5000000    $5,000,000
# 2  toyota   Blue          32549      3   7000000    $7,000,000
# 3     bmw  Black          11179      5  22000000   $22,000,000
# 4  nissan  White         213095      4   3500000    $3,500,000
# 5  toyota  Green          99213      4   4500000    $4,500,000
# 6   honda   Blue          45698      4   7500000    $7,500,000
# 7   honda   Blue          54738      4   7000000    $7,000,000
# 8  toyota  White          60000      4   6250000    $6,250,000
# 9  nissan  White          31600      4   9700000    $9,700,000

# %%
car_sales["Mileage (km/l)"]=pd.Series([19,17.5,22,11.4,21.7])

# %% [raw]
# car_sales

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price Price_display  Mileage  \
# 0  toyota  White         150043      4   4000000    $4,000,000     19.0
# 1   honda    Red          87899      4   5000000    $5,000,000     17.5
# 2  toyota   Blue          32549      3   7000000    $7,000,000     22.0
# 3     bmw  Black          11179      5  22000000   $22,000,000     11.4
# 4  nissan  White         213095      4   3500000    $3,500,000     21.7
# 5  toyota  Green          99213      4   4500000    $4,500,000     20.0
# 6   honda   Blue          45698      4   7500000    $7,500,000     20.0
# 7   honda   Blue          54738      4   7000000    $7,000,000     20.0
# 8  toyota  White          60000      4   6250000    $6,250,000     20.0
# 9  nissan  White          31600      4   9700000    $9,700,000     20.0
#
#    Mileage (km/l)
# 0            19.0
# 1            17.5
# 2            22.0
# 3            11.4
# 4            21.7
# 5             NaN
# 6             NaN
# 7             NaN
# ...

# %%
car_sales["Mileage (km/l)"]=car_sales["Mileage (km/l)"].fillna(20)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price Price_display  Mileage  \
# 0  toyota  White         150043      4   4000000    $4,000,000     19.0
# 1   honda    Red          87899      4   5000000    $5,000,000     17.5
# 2  toyota   Blue          32549      3   7000000    $7,000,000     22.0
# 3     bmw  Black          11179      5  22000000   $22,000,000     11.4
# 4  nissan  White         213095      4   3500000    $3,500,000     21.7
# 5  toyota  Green          99213      4   4500000    $4,500,000     20.0
# 6   honda   Blue          45698      4   7500000    $7,500,000     20.0
# 7   honda   Blue          54738      4   7000000    $7,000,000     20.0
# 8  toyota  White          60000      4   6250000    $6,250,000     20.0
# 9  nissan  White          31600      4   9700000    $9,700,000     20.0
#
#    Mileage (km/l)
# 0            19.0
# 1            17.5
# 2            22.0
# 3            11.4
# 4            21.7
# 5            20.0
# 6            20.0
# 7            20.0
# ...

# %%
car_sales["Total Fuel consumption"]=car_sales["Odometer (KM)"]/car_sales["Mileage"].astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price Price_display  Mileage  \
# 0  toyota  White         150043      4   4000000    $4,000,000     19.0
# 1   honda    Red          87899      4   5000000    $5,000,000     17.5
# 2  toyota   Blue          32549      3   7000000    $7,000,000     22.0
# 3     bmw  Black          11179      5  22000000   $22,000,000     11.4
# 4  nissan  White         213095      4   3500000    $3,500,000     21.7
# 5  toyota  Green          99213      4   4500000    $4,500,000     20.0
# 6   honda   Blue          45698      4   7500000    $7,500,000     20.0
# 7   honda   Blue          54738      4   7000000    $7,000,000     20.0
# 8  toyota  White          60000      4   6250000    $6,250,000     20.0
# 9  nissan  White          31600      4   9700000    $9,700,000     20.0
#
#    Mileage (km/l)  Total Fuel consumption
# 0            19.0             7897.000000
# 1            17.5             5170.529412
# 2            22.0             1479.500000
# ...

# %%
car_sales["Total Fuel consumption"]=car_sales["Total Fuel consumption"].astype(int)

# %%
car_sales["Total Fuel consumption"].dtype
# Out:
# dtype('int64')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price Price_display  Mileage  \
# 0  toyota  White         150043      4   4000000    $4,000,000     19.0
# 1   honda    Red          87899      4   5000000    $5,000,000     17.5
# 2  toyota   Blue          32549      3   7000000    $7,000,000     22.0
# 3     bmw  Black          11179      5  22000000   $22,000,000     11.4
# 4  nissan  White         213095      4   3500000    $3,500,000     21.7
# 5  toyota  Green          99213      4   4500000    $4,500,000     20.0
# 6   honda   Blue          45698      4   7500000    $7,500,000     20.0
# 7   honda   Blue          54738      4   7000000    $7,000,000     20.0
# 8  toyota  White          60000      4   6250000    $6,250,000     20.0
# 9  nissan  White          31600      4   9700000    $9,700,000     20.0
#
#    Mileage (km/l)  Total Fuel consumption
# 0            19.0                    7897
# 1            17.5                    5170
# 2            22.0                    1479
# ...

# %%
car_sales=car_sales.drop("Mileage",axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price Price_display  \
# 0  toyota  White         150043      4   4000000    $4,000,000
# 1   honda    Red          87899      4   5000000    $5,000,000
# 2  toyota   Blue          32549      3   7000000    $7,000,000
# 3     bmw  Black          11179      5  22000000   $22,000,000
# 4  nissan  White         213095      4   3500000    $3,500,000
# 5  toyota  Green          99213      4   4500000    $4,500,000
# 6   honda   Blue          45698      4   7500000    $7,500,000
# 7   honda   Blue          54738      4   7000000    $7,000,000
# 8  toyota  White          60000      4   6250000    $6,250,000
# 9  nissan  White          31600      4   9700000    $9,700,000
#
#    Mileage (km/l)  Total Fuel consumption
# 0            19.0                    7897
# 1            17.5                    5170
# 2            22.0                    1479
# 3            11.4                    1016
# 4            21.7                   10147
# ...

# %%
car_sales["Price"]=car_sales["Price"]*10
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Price_display  Mileage (km/l)  \
# 0  toyota  White         150043      4   4000.0    $4,000,000            19.0
# 1   honda    Red          87899      4   5000.0    $5,000,000            17.5
# 2  toyota   Blue          32549      3   7000.0    $7,000,000            22.0
# 3     bmw  Black          11179      5  22000.0   $22,000,000            11.4
# 4  nissan  White         213095      4   3500.0    $3,500,000            21.7
# 5  toyota  Green          99213      4   4500.0    $4,500,000            20.0
# 6   honda   Blue          45698      4   7500.0    $7,500,000            20.0
# 7   honda   Blue          54738      4   7000.0    $7,000,000            20.0
# 8  toyota  White          60000      4   6250.0    $6,250,000            20.0
# 9  nissan  White          31600      4   9700.0    $9,700,000            20.0
#
#    Total Fuel consumption
# 0                    7897
# 1                    5170
# 2                    1479
# ...

# %%
car_sales["Price_display"]=car_sales["Price"].apply(lambda x:f"${x:,}")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Price_display  Mileage (km/l)  \
# 0  toyota  White         150043      4   4000.0      $4,000.0            19.0
# 1   honda    Red          87899      4   5000.0      $5,000.0            17.5
# 2  toyota   Blue          32549      3   7000.0      $7,000.0            22.0
# 3     bmw  Black          11179      5  22000.0     $22,000.0            11.4
# 4  nissan  White         213095      4   3500.0      $3,500.0            21.7
# 5  toyota  Green          99213      4   4500.0      $4,500.0            20.0
# 6   honda   Blue          45698      4   7500.0      $7,500.0            20.0
# 7   honda   Blue          54738      4   7000.0      $7,000.0            20.0
# 8  toyota  White          60000      4   6250.0      $6,250.0            20.0
# 9  nissan  White          31600      4   9700.0      $9,700.0            20.0
#
#    Total Fuel consumption
# 0                    7897
# 1                    5170
# 2                    1479
# ...

# %%
car_sales=car_sales.drop("Price",axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors Price_display  Mileage (km/l)  \
# 0  toyota  White         150043      4      $4,000.0            19.0
# 1   honda    Red          87899      4      $5,000.0            17.5
# 2  toyota   Blue          32549      3      $7,000.0            22.0
# 3     bmw  Black          11179      5     $22,000.0            11.4
# 4  nissan  White         213095      4      $3,500.0            21.7
# 5  toyota  Green          99213      4      $4,500.0            20.0
# 6   honda   Blue          45698      4      $7,500.0            20.0
# 7   honda   Blue          54738      4      $7,000.0            20.0
# 8  toyota  White          60000      4      $6,250.0            20.0
# 9  nissan  White          31600      4      $9,700.0            20.0
#
#    Total Fuel consumption
# 0                    7897
# 1                    5170
# 2                    1479
# 3                    1016
# 4                   10147
# 5                    4960
# ...
